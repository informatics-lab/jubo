# %%
from sys import path
path.append('/Users/theo/repos/jubo')
from bokeh.io import output_notebook, show
from jubo.io import noshow
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="221ea643-a9c1-40df-bc6c-550331bb42ca">Loading BokehJS ...</span>
#     </div>

# %%
# myapp.py

from random import random

from bokeh.layouts import column, row
from bokeh.models import Button
from bokeh.palettes import RdYlBu3
from bokeh.plotting import figure, curdoc

# %%
# create a plot and style its properties
p = figure(x_range=(0, 100), y_range=(0, 100), toolbar_location=None)
p.border_fill_color = 'black'
p.background_fill_color = 'black'
p.outline_line_color = None
p.grid.grid_line_color = None
p2 = figure()

# add a text renderer to our plot (no data yet)
r = p.text(x=[], y=[], text=[], text_color=[], text_font_size="20pt",
           text_baseline="middle", text_align="center")

l = p2.step(x=[], y=[], line_width=2, mode="center")


i = 0

ds = r.data_source
ds_l = l.data_source

# create a callback that will add a number in a random location
def callback():
    global i

    # BEST PRACTICE --- update .data in one step with a new dict
    new_data = dict()
    rand1, rand2 = random()*70 + 15, random()*70 + 15
    new_data['x'] = ds.data['x'] + [rand1]
    new_data['y'] = ds.data['y'] + [rand2]
    new_data['text_color'] = ds.data['text_color'] + [RdYlBu3[i%3]]
    new_data['text'] = ds.data['text'] + [str(i)]
    ds.data = new_data
    
    l_new_data = dict()
    
    l_new_data['x'] = ds_l.data['x'] + [len(ds_l.data['x'])]
    l_new_data['y'] = ds_l.data['y'] + [rand1*rand2]
    ds_l.data = l_new_data
    i = i + 1

# add a button widget and configure with the call back
button = Button(label="Press Me")
button.on_click(callback)

# %%
noshow(p)

# %%
(row(column(button,p),p2))
# Out:
# Row(id='b2ac0844-28a8-4a73-a760-79ff6d39da9c', ...)
